# %% [markdown]
# ### Visualize the `convective_envelope_rsg` dataset

# %%
import glob

import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
# print the list of paths of files in the training set
set_path = "train"
paths = sorted(glob.glob(f"data/{set_path}/*.hdf5"))
print(paths)
# Out:
# ['data/train/convective_envelope_rsg_trajectories_0.hdf5', 'data/train/convective_envelope_rsg_trajectories_1.hdf5', 'data/train/convective_envelope_rsg_trajectories_10.hdf5', 'data/train/convective_envelope_rsg_trajectories_12.hdf5', 'data/train/convective_envelope_rsg_trajectories_13.hdf5', 'data/train/convective_envelope_rsg_trajectories_14.hdf5', 'data/train/convective_envelope_rsg_trajectories_15.hdf5', 'data/train/convective_envelope_rsg_trajectories_16.hdf5', 'data/train/convective_envelope_rsg_trajectories_18.hdf5', 'data/train/convective_envelope_rsg_trajectories_19.hdf5', 'data/train/convective_envelope_rsg_trajectories_2.hdf5', 'data/train/convective_envelope_rsg_trajectories_21.hdf5', 'data/train/convective_envelope_rsg_trajectories_22.hdf5', 'data/train/convective_envelope_rsg_trajectories_23.hdf5', 'data/train/convective_envelope_rsg_trajectories_25.hdf5', 'data/train/convective_envelope_rsg_trajectories_27.hdf5', 'data/train/convective_envelope_rsg_trajectories_28.hdf5', 'data/train/convective_envelope_rsg_trajectories_4.hdf5', 'data/train/convective_envelope_rsg_trajectories_5.hdf5', 'data/train/convective_envelope_rsg_trajectories_6.hdf5', 'data/train/convective_envelope_rsg_trajectories_7.hdf5', 'data/train/convective_envelope_rsg_trajectories_8.hdf5', 'data/train/convective_envelope_rsg_trajectories_9.hdf5']

# %%
# select the tenth path
p = paths[10]

# print the first layer of keys
with h5py.File(p, "r") as f:
    print(f["dimensions"].keys())
# We can notice that this dataset is in spehrical coordinates.
# Out:
# <KeysViewHDF5 ['phi', 'r', 'theta', 'time']>

# %%
# In 'boundary_conditions' is stored the information about the boundary conditions:
with h5py.File(p, "r") as f:
    print("print bc available:", f["boundary_conditions"].keys())
    print("print attributes of the bc:", f["boundary_conditions"]["r_open"].attrs.keys())
    print("get the bc type:", f["boundary_conditions"]["r_open"].attrs["bc_type"])
# Out:
# print bc available: <KeysViewHDF5 ['phi_periodic', 'r_open', 'theta_periodic']>
# print attributes of the bc: <KeysViewHDF5 ['associated_dims', 'associated_fields', 'bc_type', 'sample_varying', 'time_varying']>
# get the bc type: OPEN

# %%
# Reminder: 't0_fields', 't1_fields', 't2_fields' are respectively scalar fields, vector fields and tensor fields
# print the different fields available in the dataset
with h5py.File(p, "r") as f:
    print("t0_fields:", f["t0_fields"].keys())
    print("t1_fields:", f["t1_fields"].keys())
    print("t2_fields:", f["t2_fields"].keys())
# Out:
# t0_fields: <KeysViewHDF5 ['density', 'energy', 'pressure']>
# t1_fields: <KeysViewHDF5 ['velocity']>
# t2_fields: <KeysViewHDF5 []>

# %%
# The data is stored in the shape (n_trajectories, n_timesteps, x, y, z)
# Get the first t0_field and store it in a numpy array
traj = 0  # select the trajectory
with h5py.File(p, "r") as f:
    density = f["t0_fields"]["density"][traj, :]  # HDF5 datasets can be sliced (and streamed) like a numpy array
    print("shape of the selected t0_field: ", density.shape)
# Out:
# shape of the selected t0_field:  (100, 256, 128, 256)

# %%
# select the slice along the x-axis to plot:
r_slice = 40
traj_toplot = density[:, r_slice, :, :]

# field is now of shape (n_timesteps, x, y).
# Let's do a subplot to plot it at t= 0, t= T/3, t= 2T/3 and t= T:
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
T = traj_toplot.shape[0]

# same colorbar for all subplots:
normalize_plots = False
cmap = "magma"

if normalize_plots:
    vmin = np.nanmin(traj_toplot)
    vmax = np.nanmax(traj_toplot)
    norm = plt.Normalize(vmin=vmin, vmax=vmax)
    for i, t in enumerate([0, T // 3, (2 * T) // 3, T - 1]):
        axs[i].imshow(traj_toplot[t], cmap=cmap, norm=norm)
        axs[i].set_xticks([])
        axs[i].set_yticks([])
        axs[i].set_title(f't={t}')
else:
    for i, t in enumerate([0, T // 3, (2 * T) // 3, T - 1]):
        axs[i].imshow(traj_toplot[t], cmap=cmap)
        axs[i].set_xticks([])
        axs[i].set_yticks([])
        axs[i].set_title(f't={t}')
plt.tight_layout()
